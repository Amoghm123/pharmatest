# %%
pip install refractio[snowflake]
# Out:
# ...
#      |████████████████████████████████| 12.3MB 17.5MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.5MB 35.9MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 348kB 54.7MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 235kB 40.6MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 18.2MB 47.8MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 512kB 30.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 112kB 42.1MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61kB 9.5MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 61kB 9.2MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 163kB 53.3MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.4MB 47.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 71kB 11.9MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 71kB 12.9MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 143kB 50.9MB/s eta 0:00:01
# ...

# %%
from refractio import snowflake
import matplotlib.pyplot as plt
import pandas as pd
# To read a specific dataset published from a snowflake connection with only top few records.
x=snowflake.execute_query("show USERS;")
print(x)
# Out:
# Connection manager service url initialised to http://fdc-project-manager:80/project-manager
# If you need to update its value then update the variable CONNECTION_MANAGER_BASE_URL in os env.
# User name picked from OS env: amogh.mothkur@fosfor.com
# Fetching connections created by amogh.mothkur@fosfor.com user
# Connection names fetched ['pharmaconn1', 'PharmaDB', 'Snowflake pharma'], created by amogh.mothkur@fosfor.com
# Connection object created: <snowflake.connector.connection.SnowflakeConnection object at 0x7f7c444d2620>
# Please close the connection after use!
# Exception occurred in execute_query: Unknown error
# None

# %%
snowflake.get_connection('Snowflake pharma')
# Out:
# Existing connection object fetched: <snowflake.connector.connection.SnowflakeConnection object at 0x7f7c444d2620>
# Please close the connection after use!

# %%
snowflake.get_dataframe(PHYSICIAN_F)

# %%
snowflake.execute_query(f"SELECT * FROM pharma.public.PHYSICIAN_FINAL_2 limit 10")
# Out:
# User name picked from OS env: amogh.mothkur@fosfor.com
# Fetching connections created by amogh.mothkur@fosfor.com user
# Connection names fetched ['pharmaconn1', 'PharmaDB', 'Snowflake pharma'], created by amogh.mothkur@fosfor.com
# Connection object created: <snowflake.connector.connection.SnowflakeConnection object at 0x7f7c1c190f40>
# Please close the connection after use!
#   PHYSICIAN_ID   IMS_ID      NPI_ID             ADDRESS          STATE CITY
# 0      6089037  6089038  1871526343  12400 S Harlem Ave  Palos Heights   IL  \
# 1      6089037  6089038  1871526343  12400 S Harlem Ave  Palos Heights   IL
# 2      6089037  6089038  1871526343  12400 S Harlem Ave  Palos Heights   IL
# 3      6089037  6089038  1871526343  12400 S Harlem Ave  Palos Heights   IL
# 4      6089037  6089038  1871526343  12400 S Harlem Ave  Palos Heights   IL
# 5      6089037  6089038  1871526343  12400 S Harlem Ave  Palos Heights   IL
# ...

# %%
print(t)
# Out:
#   PHYSICIAN_ID   IMS_ID      NPI_ID        ADDRESS   STATE CITY ZIP_CODE
# 0      6088550  6088551  1912027582  190 N Main St  Natick   MA     1760  \
# 1      6088550  6088551  1912027582  190 N Main St  Natick   MA     1760
# 2      6088550  6088551  1912027582  190 N Main St  Natick   MA     1760
# 3      6088550  6088551  1912027582  190 N Main St  Natick   MA     1760
# 4      6088550  6088551  1912027582  190 N Main St  Natick   MA     1760
# 5      6088550  6088551  1912027582  190 N Main St  Natick   MA     1760
# 6      6088550  6088551  1912027582  190 N Main St  Natick   MA     1760
# 7      6088550  6088551  1912027582  190 N Main St  Natick   MA     1760
# 8      6088550  6088551  1912027582  190 N Main St  Natick   MA     1760
# 9      6088550  6088551  1912027582  190 N Main St  Natick   MA     1760
#
#           PHYSICIAN_NAME                SPECIALTY         SPECIALTY_GROUP
# 0  Aurobindo Chakraborty  Cardiovascular Diseases  Primary Care Physician  \
# ...

# %%
dir(snowflake)
# Out:
# ['_Snowflake__connection_details',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_connection',
#  'close_connection',
#  'con_obj',
#  'execute_query',
#  'get_connection',
#  'get_dataframe']

# %%
conn = snowflake.get_connection('Snowflake_vikas')
# Out:
# Existing connection object fetched: <snowflake.connector.connection.SnowflakeConnection object at 0x7f47abf02530>
# Please close the connection after use!

# %%
#snowflake.get_connection()
cursor_1 = con.cursor()
x=cursor_1.execute("show USERS")
print(x)

# %%
table = snowflake.execute_query(f"SELECT * FROM FDC.INSIGHT_DESIGNER.FORECASTED_DATA" )

# %%
table
# Out:
#           BRAND        REGION  MONTH  FORECASTED_TRX
# 0    ALPHATUMAB  Mid-Atlantic     24    10616.569346
# 1    ALPHATUMAB  Mid-Atlantic     25    11374.813248
# 2    ALPHATUMAB  Mid-Atlantic     26    11156.823132
# 3    ALPHATUMAB  Mid-Atlantic     27    11219.493851
# 4    ALPHATUMAB  Mid-Atlantic     28    11201.476433
# ..          ...           ...    ...             ...
# 359    ZELDATAB          West     32    17753.429844
# 360    ZELDATAB          West     33    17753.420338
# 361    ZELDATAB          West     34    17753.417689
# 362    ZELDATAB          West     35    17753.416950
# 363    ZELDATAB          West     36    17753.416744
#
# [364 rows x 4 columns]

# %%
table=snowflake.get_dataframe("physician_fact_1")
# Out:
# Connection details fetched: {'errorCode': 'CNM-404', 'message': 'Asset not found', 'detailMessage': 'Datasource not found by name physician_fact_1', 'timeStamp': '2024-05-23 13:06:31.269', 'api': '/v1/external/getConnConfig/{dataSourceName}/{userId}/{projectId}'}
# Ex: 'params'
# Exception occurred in reading data_frame from snowflake connection: Exception occurred in creating snowflake connection: Datasource not found by name physician_fact_1
